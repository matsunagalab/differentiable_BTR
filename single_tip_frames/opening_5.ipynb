# %% [markdown]
# This notebook peforms a blind tip reconstruction using the gradient decent of the opening from noisy image data

# %% [markdown]
# ## load required packages and test data

# %%
using Flux
using Flux.Data: DataLoader
using Plots
using BSON: @save, @load
using Statistics
using Random
using Revise, MDToolbox
ENV["COLUMNS"] = 150; #display width for MDToolbox

# %%
@load "prepare_test_data.bson" width height resolution radius angle param models tip nx ny surfs images images_randn

# %%
tip
# Out:
# 10×10 Matrix{Float64}:
#  -364.442  -308.564  -263.659   -233.967   -223.495   -233.967   -263.659   -308.564  -364.442  -427.927
#  -308.564  -244.136  -189.939   -152.23    -138.426   -152.23    -189.939   -244.136  -308.564  -379.253
#  -263.659  -189.939  -123.83     -73.4385   -53.3564   -73.4385  -123.83    -189.939  -263.659  -341.33
#  -233.967  -152.23    -73.4385   -11.7712    -5.0      -11.7712   -73.4385  -152.23   -233.967  -316.988
#  -223.495  -138.426   -53.3564    -5.0        0.0       -5.0      -53.3564  -138.426  -223.495  -308.564
#  -233.967  -152.23    -73.4385   -11.7712    -5.0      -11.7712   -73.4385  -152.23   -233.967  -316.988
#  -263.659  -189.939  -123.83     -73.4385   -53.3564   -73.4385  -123.83    -189.939  -263.659  -341.33
#  -308.564  -244.136  -189.939   -152.23    -138.426   -152.23    -189.939   -244.136  -308.564  -379.253
#  -364.442  -308.564  -263.659   -233.967   -223.495   -233.967   -263.659   -308.564  -364.442  -427.927
#  -427.927  -379.253  -341.33    -316.988   -308.564   -316.988   -341.33    -379.253  -427.927  -484.748

# %%
MDToolbox.translate_tip_mean(tip)
# Out:
# 10×10 Matrix{Float64}:
#  -364.442  -308.564  -263.659   -233.967   -223.495   -233.967   -263.659   -308.564  -364.442  -427.927
#  -308.564  -244.136  -189.939   -152.23    -138.426   -152.23    -189.939   -244.136  -308.564  -379.253
#  -263.659  -189.939  -123.83     -73.4385   -53.3564   -73.4385  -123.83    -189.939  -263.659  -341.33
#  -233.967  -152.23    -73.4385   -11.7712    -5.0      -11.7712   -73.4385  -152.23   -233.967  -316.988
#  -223.495  -138.426   -53.3564    -5.0        0.0       -5.0      -53.3564  -138.426  -223.495  -308.564
#  -233.967  -152.23    -73.4385   -11.7712    -5.0      -11.7712   -73.4385  -152.23   -233.967  -316.988
#  -263.659  -189.939  -123.83     -73.4385   -53.3564   -73.4385  -123.83    -189.939  -263.659  -341.33
#  -308.564  -244.136  -189.939   -152.23    -138.426   -152.23    -189.939   -244.136  -308.564  -379.253
#  -364.442  -308.564  -263.659   -233.967   -223.495   -233.967   -263.659   -308.564  -364.442  -427.927
#  -427.927  -379.253  -341.33    -316.988   -308.564   -316.988   -341.33    -379.253  -427.927  -484.748

# %% [markdown]
# ## Define Flux layers

# %%
struct IOpen
    P::AbstractArray
end

IOpen(height::Integer, width::Integer) = IOpen(zeros(Float64, height, width))

Flux.@functor IOpen (P,)

(m::IOpen)(image) = idilation(ierosion(image, m.P), m.P)

# %% [markdown]
# ## loop over lambda

# %%
nframe = 5
nrealization = 100
Random.seed!(777);
loss_over_lambdas_array = []
P_over_lambdas_array = []
#lambdas = [0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.1]
lambdas = [0.0000001, 0.000001, 0.00001, 0.0001, 0.001, 0.01]

for irealization = 1:nrealization
    @info irealization

    for iframe = 1:length(images)
        images_randn[iframe] .= images[iframe] .+ 3.0 .* randn(Float64, size(images[iframe]))
    end
    images_randn_copy = deepcopy(images_randn)

    loss_over_lambdas = []
    P_over_lambdas = []

    for lambda in lambdas
        @info lambda

        m = IOpen(ny, nx)

        #loss(image_randn_copy, image_randn) = mean(Flux.Losses.mse.(m.(image_randn_copy), image_randn)) + lambda * sum( -m.P .* log.(-m.P .+ eps(Float32)))
        #loss(image_randn_copy, image_randn) = mean(Flux.Losses.mse.(m.(image_randn_copy), image_randn)) + lambda * sum( m.P.^2 )
        #loss(image_randn_copy, image_randn) = mean(Flux.Losses.mse.(m.(image_randn_copy), image_randn)) + lambda * sum( - m.P )
        loss(image_randn_copy, image_randn) = mean(Flux.Losses.mse.(m.(image_randn_copy), image_randn))

        ps = Flux.params(m)

        train_loader = Flux.Data.DataLoader((data=images_randn_copy[1:nframe], label=images_randn[1:nframe]), batchsize=1, shuffle=false);

        #opt = ADAM(0.1)
        opt = ADAMW(1.0, (0.9, 0.999), lambda)
    
        loss_train = []

        for epoch in 1:10000
            for (x, y) in train_loader
                gs = gradient(() -> loss(x, y), ps)
                Flux.Optimise.update!(opt, ps, gs)
                m.P .= min.(m.P, 0.0)
                m.P .= MDToolbox.translate_tip_mean(m.P)
                #m.P .= MDToolbox.translate_tip_peak(m.P)
            end
            push!(loss_train, loss(images_randn_copy[1:nframe], images_randn[1:nframe]))
        end

        push!(loss_over_lambdas, loss_train[end])
        push!(P_over_lambdas, m.P)
    end
    
    push!(loss_over_lambdas_array, loss_over_lambdas)
    push!(P_over_lambdas_array, P_over_lambdas)
end
# Out:
# ┌ Info: 1
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 2
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 3
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 4
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 5
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 6
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 7
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 8
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 9
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 10
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 11
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 12
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 13
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 14
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 15
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 16
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 17
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 18
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 19
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 20
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 21
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 22
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 23
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 24
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 25
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 26
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 27
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 28
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 29
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 30
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 31
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 32
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 33
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 34
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 35
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 36
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 37
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 38
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 39
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 40
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 41
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 42
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 43
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 44
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 45
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 46
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 47
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 48
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 49
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 50
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 51
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 52
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 53
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 54
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 55
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 56
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 57
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 58
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 59
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 60
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 61
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 62
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 63
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 64
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 65
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 66
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 67
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 68
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 69
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 70
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 71
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 72
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 73
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 74
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 75
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 76
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 77
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 78
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 79
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 80
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 81
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 82
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 83
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 84
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 85
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 86
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 87
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 88
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 89
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 90
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 91
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 92
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 93
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 94
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 95
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 96
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 97
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 98
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 99
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21
# ┌ Info: 100
# └ @ Main In[6]:10
# ┌ Info: 1.0e-7
# └ @ Main In[6]:21
# ┌ Info: 1.0e-6
# └ @ Main In[6]:21
# ┌ Info: 1.0e-5
# └ @ Main In[6]:21
# ┌ Info: 0.0001
# └ @ Main In[6]:21
# ┌ Info: 0.001
# └ @ Main In[6]:21
# ┌ Info: 0.01
# └ @ Main In[6]:21

# %%
loss_over_lambdas_array[1]
# Out:
# 6-element Vector{Any}:
#    7.67744938520468
#    9.688740333162688
#   11.91650835887691
#    6.054848000441931
#    7.0100847945524425
#  136.79127109503438

# %%
tip
# Out:
# 10×10 Matrix{Float64}:
#  -364.442  -308.564  -263.659   -233.967   -223.495   -233.967   -263.659   -308.564  -364.442  -427.927
#  -308.564  -244.136  -189.939   -152.23    -138.426   -152.23    -189.939   -244.136  -308.564  -379.253
#  -263.659  -189.939  -123.83     -73.4385   -53.3564   -73.4385  -123.83    -189.939  -263.659  -341.33
#  -233.967  -152.23    -73.4385   -11.7712    -5.0      -11.7712   -73.4385  -152.23   -233.967  -316.988
#  -223.495  -138.426   -53.3564    -5.0        0.0       -5.0      -53.3564  -138.426  -223.495  -308.564
#  -233.967  -152.23    -73.4385   -11.7712    -5.0      -11.7712   -73.4385  -152.23   -233.967  -316.988
#  -263.659  -189.939  -123.83     -73.4385   -53.3564   -73.4385  -123.83    -189.939  -263.659  -341.33
#  -308.564  -244.136  -189.939   -152.23    -138.426   -152.23    -189.939   -244.136  -308.564  -379.253
#  -364.442  -308.564  -263.659   -233.967   -223.495   -233.967   -263.659   -308.564  -364.442  -427.927
#  -427.927  -379.253  -341.33    -316.988   -308.564   -316.988   -341.33    -379.253  -427.927  -484.748

# %%
P_over_lambdas_array[1][1]
# Out:
# 10×10 Matrix{Float64}:
#  -134.443   -123.578   -119.297   -129.752    -132.18     -121.222   -123.087   -131.044  -124.677  -121.972
#  -129.592   -134.981   -121.247    -98.3568    -54.615     -76.9728  -123.255   -128.479  -120.054  -145.584
#  -118.216    -98.1606   -83.6296   -10.7402     -7.68145   -13.7855   -70.1503  -125.83   -126.67   -115.542
#   -73.4455   -69.7939   -68.4375     0.0        -8.68523    -7.5194   -54.7694  -130.247  -119.117  -127.104
#  -104.175    -83.368    -69.5587    -7.32798   -10.0387     -8.85     -76.6772  -113.732  -138.297  -132.764
#  -110.34     -93.0292   -72.3402   -30.6427    -21.599     -31.2586   -91.0524  -128.088  -139.454  -116.123
#  -112.798   -108.769    -98.2848   -89.288     -91.7706    -80.407   -111.58    -121.986  -125.071  -128.471
#  -123.755   -116.772   -117.646   -104.701     -98.4297   -108.107   -116.768   -130.877  -129.815  -133.331
#  -137.602   -123.657   -130.91    -110.915    -100.921    -115.096   -127.705   -123.614  -126.362  -134.714
#  -126.477   -126.284   -125.474   -123.603    -124.499    -121.688   -119.818   -122.267  -131.805  -128.175

# %%
#gr()

# %%
#heatmap(tip)

# %%
#heatmap(P_over_lambdas_array[1][1])

# %%
plot(lambdas, loss_over_lambdas_array[1] ./ 100.0, xaxis=:log, framestyle=:box, 
     xlabel="threshold T", ylabel="loss [nm^2]", label=nothing, linewidth=0.5, dpi=150, fmt=:png, color=3, 
     xtickfontsize=12, ytickfontsize=12, legendfontsize=12)

l_mean = deepcopy(loss_over_lambdas_array[1] ./ 100.0)
for i = 2:nrealization
    plot!(lambdas, loss_over_lambdas_array[i] ./ 100.0, xaxis=:log, framestyle=:box, xlabel="threshold T", ylabel="loss [nm^2]", 
          label=nothing, linewidth=0.5, dpi=150, fmt=:png, color=3)
    l_mean .+= (loss_over_lambdas_array[i] ./ 100.0)
end
l_mean .= l_mean ./ nrealization

l_std = deepcopy(l_mean)
l_std .= 0.0
for i = 1:nrealization
    l_std .+= ((loss_over_lambdas_array[i] ./ 100.0) .- l_mean).^2
end
l_std .= l_std ./ (nrealization - 1.0)

#plot!(lambdas, l_mean, ribbon=l_std, fillalpha=0.5, color=3, linewidth=0.0, legend=nothing)

ylims!(-0.05, 2.3)
xlabel!("lambda", fontsize=35)
p = ylabel!("Loss [nm^2]", fontsize=35)

# %%
#gr()

# %%
tip
# Out:
# 10×10 Matrix{Float64}:
#  -364.442  -308.564  -263.659   -233.967   -223.495   -233.967   -263.659   -308.564  -364.442  -427.927
#  -308.564  -244.136  -189.939   -152.23    -138.426   -152.23    -189.939   -244.136  -308.564  -379.253
#  -263.659  -189.939  -123.83     -73.4385   -53.3564   -73.4385  -123.83    -189.939  -263.659  -341.33
#  -233.967  -152.23    -73.4385   -11.7712    -5.0      -11.7712   -73.4385  -152.23   -233.967  -316.988
#  -223.495  -138.426   -53.3564    -5.0        0.0       -5.0      -53.3564  -138.426  -223.495  -308.564
#  -233.967  -152.23    -73.4385   -11.7712    -5.0      -11.7712   -73.4385  -152.23   -233.967  -316.988
#  -263.659  -189.939  -123.83     -73.4385   -53.3564   -73.4385  -123.83    -189.939  -263.659  -341.33
#  -308.564  -244.136  -189.939   -152.23    -138.426   -152.23    -189.939   -244.136  -308.564  -379.253
#  -364.442  -308.564  -263.659   -233.967   -223.495   -233.967   -263.659   -308.564  -364.442  -427.927
#  -427.927  -379.253  -341.33    -316.988   -308.564   -316.988   -341.33    -379.253  -427.927  -484.748

# %%
it = 2
islice = 5
cutoff = 80.0

plot(collect(1:nx) .* resolution ./ 10.0, P_over_lambdas_array[1][it][islice, :] / 10.0, linewidth=0.5, linestyle=:dot, color=3, label=nothing, framestyle=:box, dpi=150, fmt=:png, legend=nothing)
p_mean = deepcopy(P_over_lambdas_array[1][it][islice, :] ./ 10.0)
for irealization = 2:nrealization
    plot!(collect(1:nx) .* resolution ./ 10.0, P_over_lambdas_array[irealization][it][islice, :] / 10.0, linewidth=0.5, linestyle=:dot, color=3, label=nothing, framestyle=:box, dpi=150, fmt=:png, legend=nothing)
    p_mean .+= P_over_lambdas_array[irealization][it][islice, :] ./ 10.0
end
p_mean .= p_mean ./ nrealization

p_std = deepcopy(p_mean)
p_std .= 0.0
for irealization = 1:nrealization
    p_std .+= (P_over_lambdas_array[irealization][it][islice, :] ./ 10.0 .- p_mean).^2
end
p_std .= p_std ./ (nrealization - 1.0)

plot!(collect(1:nx) .* resolution ./ 10.0, p_mean, ribbon=p_std, fillalpha=0.3, color=3)

plot!((collect(1:nx)) .* resolution ./ 10.0, tip[islice, :] ./ 10.0, linewidth=3, label="ground truth", legend=nothing, color=2, 
      xtickfontsize=12, ytickfontsize=12, legendfontsize=12)

ylims!((-10, 0.5))
xlims!((2, 13))
xlabel!("X coordinate [nm]", fontsize=35)
p = ylabel!("Tip height [nm]", fontsize=35)

# %%
it = 1
islice = 5

plot(collect(1:ny) .* resolution ./ 10.0, P_over_lambdas_array[1][it][:, islice] / 10.0, 
    linewidth=0.5, linestyle=:dot, color=3, label=nothing, framestyle=:box, dpi=150, fmt=:png, legend=nothing)
p_mean = deepcopy(P_over_lambdas_array[1][it][:, islice] ./ 10.0)
for irealization = 2:nrealization
    plot!(collect(1:ny) .* resolution / 10.0, P_over_lambdas_array[irealization][it][:, islice] ./ 10.0, 
        linewidth=0.5, linestyle=:dot, color=3, label=nothing, framestyle=:box, dpi=150, fmt=:png, legend=nothing)
    p_mean .+= P_over_lambdas_array[irealization][it][:, islice] ./ 10.0
end
p_mean .= p_mean ./ nrealization

p_std = deepcopy(p_mean)
p_std .= 0.0
for irealization = 1:nrealization
    p_std .+= (P_over_lambdas_array[irealization][it][:, islice] ./ 10.0 .- p_mean).^2
end
p_std .= p_std ./ (nrealization - 1.0)

plot!(collect(1:ny) .* resolution ./ 10.0, p_mean, ribbon=p_std, fillalpha=0.3, color=3, linewidth=0.0)

plot!((collect(1:ny)) .* resolution ./ 10.0, tip[:, islice] / 10.0, linewidth=3, label="ground truth", legend=nothing, color=2, 
      xtickfontsize=12, ytickfontsize=12, legendfontsize=12)

ylims!((-10, 0.5))
xlims!((2, 13))

xlabel!("Y coordinate [nm]", fontsize=35)
p = ylabel!("Tip height [nm]", fontsize=35)

# %%
tip
# Out:
# 10×10 Matrix{Float64}:
#  -364.442  -308.564  -263.659   -233.967   -223.495   -233.967   -263.659   -308.564  -364.442  -427.927
#  -308.564  -244.136  -189.939   -152.23    -138.426   -152.23    -189.939   -244.136  -308.564  -379.253
#  -263.659  -189.939  -123.83     -73.4385   -53.3564   -73.4385  -123.83    -189.939  -263.659  -341.33
#  -233.967  -152.23    -73.4385   -11.7712    -5.0      -11.7712   -73.4385  -152.23   -233.967  -316.988
#  -223.495  -138.426   -53.3564    -5.0        0.0       -5.0      -53.3564  -138.426  -223.495  -308.564
#  -233.967  -152.23    -73.4385   -11.7712    -5.0      -11.7712   -73.4385  -152.23   -233.967  -316.988
#  -263.659  -189.939  -123.83     -73.4385   -53.3564   -73.4385  -123.83    -189.939  -263.659  -341.33
#  -308.564  -244.136  -189.939   -152.23    -138.426   -152.23    -189.939   -244.136  -308.564  -379.253
#  -364.442  -308.564  -263.659   -233.967   -223.495   -233.967   -263.659   -308.564  -364.442  -427.927
#  -427.927  -379.253  -341.33    -316.988   -308.564   -316.988   -341.33    -379.253  -427.927  -484.748

# %%
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
tip_tmp = deepcopy(tip)
tip_tmp[tip .< -150.0] .= NaN

plot(collect(1:nx) .* resolution ./ 10.0, collect(1:ny) .* resolution ./ 10.0, tip_tmp ./ 10.0, st=:surface, dpi=150, clims=(-12, 0),
     xtickfontsize=12, ytickfontsize=12, legendfontsize=12, colorbar_tickfontsize=12)
xlabel!("X [nm]", fontsize=35)
p = ylabel!("Y [nm]", fontsize=35)
#zlabel!("Z [nm]", fontsize=35)
#zlims!((-8, 0.5))
#zlabel!("Tip height [nm]", fontsize=35)

# %%
it = 1
ireal = 1
tip_tmp = deepcopy(P_over_lambdas_array[ireal][it])
tip_tmp[tip .< -150.0] .= NaN

plot(collect(1:nx) .* resolution ./ 10.0, collect(1:ny) .* resolution ./ 10.0, tip_tmp ./ 10.0, st=:surface, dpi=150, clims=(-12, 0), 
     xtickfontsize=12, ytickfontsize=12, legendfontsize=12, colorbar_tickfontsize=12)
xlabel!("X [nm]", fontsize=35)
p = ylabel!("Y [nm]", fontsize=35)
#zlabel!("Z [nm]", fontsize=35)
#zlims!((-8, 0.5))
#zlabel!("Tip height [nm]", fontsize=35)

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
p = heatmap(collect(1:30) .* resolution ./ 10.0, collect(1:30) .* resolution ./ 10.0, images_randn[1] ./ 10.0, clim=(0, 5), dpi=150, fmt=:png, 
            aspect_ratio=:equal, xtickfontsize=12, ytickfontsize=12, legendfontsize=12, colorbar_tickfontsize=12)
xlabel!("X coordinate [nm]", fontsize=35)
ylabel!("Y coordinate [nm]", fontsize=35)
xlims!(10, 33)
ylims!(14, 32)

# %%
p = heatmap(collect(1:30) .* resolution ./ 10.0, collect(1:30) .* resolution ./ 10.0, ierosion(images_randn[1], P_over_lambdas_array[1][1]) ./ 10.0, clim=(0, 8), dpi=150, fmt=:png, 
            aspect_ratio=:equal, xtickfontsize=12, ytickfontsize=12, legendfontsize=12, colorbar_tickfontsize=12)
xlabel!("X coordinate [nm]", fontsize=35)
ylabel!("Y coordinate [nm]", fontsize=35)
xlims!(10, 33)
ylims!(14, 32)

# %%
p = heatmap(collect(1:30) .* resolution ./ 10.0, collect(1:30) .* resolution ./ 10.0, surfs[1] ./ 10.0, clim=(0, 8), dpi=150, fmt=:png,
            aspect_ratio=:equal, xtickfontsize=12, ytickfontsize=12, legendfontsize=12, colorbar_tickfontsize=12)
xlabel!("X coordinate [nm]", fontsize=35)
ylabel!("Y coordinate [nm]", fontsize=35)
xlims!(10, 33)
ylims!(14, 32)

# %% [markdown]
# # Pixel RMSD of reconstructed tip

# %%
function pixel_rmsd(image1, image2, ref; cutoff = -70.0)
    image1_shifted = similar(image1)

    rmsd_min = Inf64
    for du = -5:5, dv = -5:5
        image1_shifted = circshift(image1, (du, dv))
        #id = (image1_shifted .> cutoff) .| (image2 .> cutoff)
        id = ref .> cutoff
        tmp = sqrt(mean((image1_shifted[id] .- image2[id]).^2))
        if tmp < rmsd_min
            rmsd_min = tmp
        end
    end
    return rmsd_min
end

diff_tip = zeros(Float64, length(lambdas)*nrealization, 2)
count = 0
for it = 1:length(lambdas)
    for ireal = 1:nrealization
        c = pixel_rmsd(P_over_lambdas_array[ireal][it], tip, tip, cutoff=-80.0)
        count += 1
        diff_tip[count, 1] = lambdas[it]
        diff_tip[count, 2] = c
    end
end

# %%
using StatsPlots
pyplot()

violin(log10.(diff_tip[:, 1]), diff_tip[:, 2] / 10.0, ylim=(-0.1, 6.0), #xaxis=:log, 
       xtickfontsize=12, ytickfontsize=12, legendfontsize=12, 
       framestyle=:box, label=nothing, linewidth=0.5, dpi=150, fmt=:png, alpha=0.6, color=3)

dotplot!(log10.(diff_tip[:, 1]), diff_tip[:, 2] / 10.0, marker=(:black,stroke(0)), mode = :density, markersize=2.0, label=nothing)

#scatter(diff_tip[:, 1] / 10.0, diff_tip[:, 2] / 10.0, xaxis=:log, framestyle = :box, xlabel="threshold T", ylabel="RMSD frome true tip [nm]", label=nothing, linewidth=1.0, markershape=:circle, dpi=150, fmt=:png, color=1, 
#        xtickfontsize=12, ytickfontsize=12, legendfontsize=10, colorbar_tickfontsize=10, markersize=12, markerstrokewidth=1)
#ylims!(-0.05, 2.3)
xlabel!("lambda", fontsize=35)
p = ylabel!("RMSD from true tip [nm]", fontsize=35)
ylims!(0.0, 6.5)

# %% [markdown]
# # Pixel RMSD of reconstructed surface

# %%
diff_surf = zeros(Float64, length(lambdas)*nrealization*nframe, 2)
count = 0
Random.seed!(777);
images_randn = deepcopy(images)

for it = 1:length(lambdas)
    for ireal = 1:nrealization
        for iframe = 1:nframe
            images_randn[iframe] .= images[iframe] .+ 3.0 .* randn(Float64, size(images[iframe]))
            c = pixel_rmsd(ierosion(images_randn[iframe], P_over_lambdas_array[ireal][it]), surfs[iframe], images[iframe], cutoff=10.0)
            count += 1
            diff_surf[count, 1] = lambdas[it]
            diff_surf[count, 2] = c
        end
    end
end

# %%
using StatsPlots
pyplot()

violin(log10.(diff_surf[:, 1]), diff_surf[:, 2] / 10.0, ylim=(-0.1, 6.0),
       xtickfontsize=12, ytickfontsize=12, legendfontsize=12, 
       xlabel="log lambda", ylabel="RMSD from true surface [nm]", 
       framestyle=:box, label=nothing, linewidth=0.5, dpi=150, fmt=:png, alpha=0.6, color=3)

dotplot!(log10.(diff_surf[:, 1]), diff_surf[:, 2] / 10.0, marker=(:black, stroke(0)), markersize=0.5, mode = :density, label=nothing)

ylims!(-0.0, 5)

# %% [markdown]
# # Save results

# %%
using BSON: @save, @load

@save "opening_$(nframe).bson" tip images nframe nrealization lambdas P_over_lambdas_array diff_tip diff_surf
