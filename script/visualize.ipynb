# %%
using DelimitedFiles
using Plots

# %%
P = readdlm("tip.csv", ',')
# Out:
# 15×15 Matrix{Float64}:
#  -119.971   -119.971   -119.971   …  -119.971    -119.971   -119.971
#  -102.596    -93.2136   -92.2544     -100.702     -94.5824  -119.971
#  -106.102   -100.604    -92.5431      -97.6736   -107.399   -120.08
#   -97.4614   -97.7374   -97.4119      -95.0046   -101.338   -119.971
#   -97.1142   -94.5071   -95.5118      -96.7084   -100.302   -120.001
#   -94.677    -95.9858   -98.7135  …   -96.6623    -93.162   -119.971
#  -102.809   -101.515    -96.978       -67.5231    -89.7171  -119.971
#  -100.27     -97.5519   -94.4704       -7.12176   -69.2456  -119.971
#   -95.564    -92.4181   -94.5228        0.0       -66.0375  -119.852
#   -95.0635   -96.5557   -92.0667       -8.87891   -66.3068  -119.971
#   -95.724    -99.5869   -91.4835  …   -74.556     -88.6102  -119.971
#   -92.572    -96.4952   -92.9616      -92.2674   -100.391   -119.971
#   -93.0718  -103.33     -92.7567      -95.3527    -97.2503  -119.971
# ...

# %%
heatmap(P)

# %%
image = readdlm("data/afm01.csv", ',')
heatmap(image)

# %%
image = readdlm("data/afm01.csv_erosion", ',')
heatmap(image)
