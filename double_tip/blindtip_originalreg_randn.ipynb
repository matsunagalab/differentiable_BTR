# %% [markdown]
# This notebook peforms Villarubia's blind tip reconstruction from noisy image data

# %% [markdown]
# ## load required packages and test data

# %%
using Flux
using Flux.Data: DataLoader
using Plots
using BSON: @save, @load
using Random
using Statistics
using Revise, MDToolbox
# Out:
# ┌ Info: Precompiling MDToolbox [7965e2f0-a35b-11e8-0207-19c030dd2def]
# └ @ Base loading.jl:1423

# %%
@load "prepare_test_data.bson" width height resolution radius angle param models tip nx ny surfs images images_randn

# %% [markdown]
# ## Blind-tip reconstruction from noisy Image

# %%
nframe = 20
nrealization = 100

T = [0.1, 1.0, 10.0, 20.0, 40.0, 80.0]
loss_over_lambdas_array = []
P_over_lambdas_array = []

Random.seed!(777);

for irealization = 1:nrealization
    @info irealization

    for iframe = 1:length(images)
        images_randn[iframe] .= images[iframe] .+ 3.0 .* randn(Float64, size(images[iframe]))
    end

    P_over_lambdas = []
    loss_over_lambdas = []

    for t in T
        m_P = similar(tip)
        m_P .= 0.0

        itip_estimate!(m_P, images_randn[1:nframe], thresh=t, iregularize=true);

        loss = 0.0
        for image in images_randn[1:nframe]
            loss += mean((idilation(ierosion(image, m_P), m_P) .- image).^2)
        end
        loss = loss / length(images_randn[1:nframe])
        
        push!(P_over_lambdas, m_P)
        push!(loss_over_lambdas, loss)
    end
    
    push!(P_over_lambdas_array, P_over_lambdas)
    push!(loss_over_lambdas_array, loss_over_lambdas)
end
# Out:
# Processed 20 image
# 69 refinements
# Processed 20 image
# 73 refinements
# Processed 20 image
# 54 refinements
# Processed 20 image
# 37 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 53 refinements
# Processed 20 image
# 53 refinements
# Processed 20 image
# 48 refinements
# Processed 20 image
# 38 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 74 refinements
# Processed 20 image
# 81 refinements
# Processed 20 image
# 38 refinements
# Processed 20 image
# 42 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 77 refinements
# Processed 20 image
# 101 refinements
# Processed 20 image
# 54 refinements
# Processed 20 image
# 44 refinements
# Processed 20 image
# 10 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 60 refinements
# Processed 20 image
# 55 refinements
# Processed 20 image
# 45 refinements
# Processed 20 image
# 39 refinements
# Processed 20 image
# 6 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 43 refinements
# Processed 20 image
# 48 refinements
# Processed 20 image
# 47 refinements
# Processed 20 image
# 23 refinements
# Processed 20 image
# 6 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 88 refinements
# Processed 20 image
# 61 refinements
# Processed 20 image
# 49 refinements
# Processed 20 image
# 39 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 51 refinements
# Processed 20 image
# 57 refinements
# Processed 20 image
# 38 refinements
# Processed 20 image
# 48 refinements
# Processed 20 image
# 6 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 84 refinements
# Processed 20 image
# 51 refinements
# Processed 20 image
# 43 refinements
# Processed 20 image
# 10 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 78 refinements
# Processed 20 image
# 58 refinements
# Processed 20 image
# 48 refinements
# Processed 20 image
# 23 refinements
# Processed 20 image
# 5 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 50 refinements
# Processed 20 image
# 47 refinements
# Processed 20 image
# 36 refinements
# Processed 20 image
# 44 refinements
# Processed 20 image
# 6 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 80 refinements
# Processed 20 image
# 83 refinements
# Processed 20 image
# 53 refinements
# Processed 20 image
# 43 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 50 refinements
# Processed 20 image
# 20 refinements
# Processed 20 image
# 8 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 83 refinements
# Processed 20 image
# 83 refinements
# Processed 20 image
# 50 refinements
# Processed 20 image
# 27 refinements
# Processed 20 image
# 8 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 64 refinements
# Processed 20 image
# 66 refinements
# Processed 20 image
# 61 refinements
# Processed 20 image
# 33 refinements
# Processed 20 image
# 8 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 67 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 62 refinements
# Processed 20 image
# 35 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 62 refinements
# Processed 20 image
# 64 refinements
# Processed 20 image
# 49 refinements
# Processed 20 image
# 48 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 70 refinements
# Processed 20 image
# 84 refinements
# Processed 20 image
# 55 refinements
# Processed 20 image
# 30 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 84 refinements
# Processed 20 image
# 72 refinements
# Processed 20 image
# 57 refinements
# Processed 20 image
# 33 refinements
# Processed 20 image
# 14 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 66 refinements
# Processed 20 image
# 50 refinements
# Processed 20 image
# 24 refinements
# Processed 20 image
# 8 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 60 refinements
# Processed 20 image
# 69 refinements
# Processed 20 image
# 50 refinements
# Processed 20 image
# 24 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 51 refinements
# Processed 20 image
# 52 refinements
# Processed 20 image
# 48 refinements
# Processed 20 image
# 24 refinements
# Processed 20 image
# 10 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 76 refinements
# Processed 20 image
# 67 refinements
# Processed 20 image
# 37 refinements
# Processed 20 image
# 44 refinements
# Processed 20 image
# 5 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 50 refinements
# Processed 20 image
# 49 refinements
# Processed 20 image
# 45 refinements
# Processed 20 image
# 25 refinements
# Processed 20 image
# 6 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 88 refinements
# Processed 20 image
# 99 refinements
# Processed 20 image
# 54 refinements
# Processed 20 image
# 34 refinements
# Processed 20 image
# 10 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 71 refinements
# Processed 20 image
# 78 refinements
# Processed 20 image
# 62 refinements
# Processed 20 image
# 27 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 54 refinements
# Processed 20 image
# 53 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 17 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 70 refinements
# Processed 20 image
# 69 refinements
# Processed 20 image
# 48 refinements
# Processed 20 image
# 35 refinements
# Processed 20 image
# 5 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 85 refinements
# Processed 20 image
# 78 refinements
# Processed 20 image
# 46 refinements
# Processed 20 image
# 33 refinements
# Processed 20 image
# 10 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 61 refinements
# Processed 20 image
# 45 refinements
# Processed 20 image
# 20 refinements
# Processed 20 image
# 4 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 77 refinements
# Processed 20 image
# 72 refinements
# Processed 20 image
# 54 refinements
# Processed 20 image
# 38 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 64 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 50 refinements
# Processed 20 image
# 35 refinements
# Processed 20 image
# 10 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 80 refinements
# Processed 20 image
# 80 refinements
# Processed 20 image
# 53 refinements
# Processed 20 image
# 31 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 58 refinements
# Processed 20 image
# 55 refinements
# Processed 20 image
# 46 refinements
# Processed 20 image
# 27 refinements
# Processed 20 image
# 7 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 59 refinements
# Processed 20 image
# 59 refinements
# Processed 20 image
# 45 refinements
# Processed 20 image
# 21 refinements
# Processed 20 image
# 8 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 51 refinements
# Processed 20 image
# 91 refinements
# Processed 20 image
# 72 refinements
# Processed 20 image
# 30 refinements
# Processed 20 image
# 6 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 63 refinements
# Processed 20 image
# 63 refinements
# Processed 20 image
# 56 refinements
# Processed 20 image
# 42 refinements
# Processed 20 image
# 13 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 62 refinements
# Processed 20 image
# 61 refinements
# Processed 20 image
# 47 refinements
# Processed 20 image
# 43 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 41 refinements
# Processed 20 image
# 39 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 69 refinements
# Processed 20 image
# 90 refinements
# Processed 20 image
# 73 refinements
# Processed 20 image
# 39 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 58 refinements
# Processed 20 image
# 58 refinements
# Processed 20 image
# 58 refinements
# Processed 20 image
# 36 refinements
# Processed 20 image
# 7 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 78 refinements
# Processed 20 image
# 64 refinements
# Processed 20 image
# 64 refinements
# Processed 20 image
# 47 refinements
# Processed 20 image
# 7 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 51 refinements
# Processed 20 image
# 51 refinements
# Processed 20 image
# 56 refinements
# Processed 20 image
# 34 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 76 refinements
# Processed 20 image
# 71 refinements
# Processed 20 image
# 64 refinements
# Processed 20 image
# 44 refinements
# Processed 20 image
# 8 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 52 refinements
# Processed 20 image
# 31 refinements
# Processed 20 image
# 13 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 58 refinements
# Processed 20 image
# 58 refinements
# Processed 20 image
# 70 refinements
# Processed 20 image
# 35 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 67 refinements
# Processed 20 image
# 58 refinements
# Processed 20 image
# 38 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 63 refinements
# Processed 20 image
# 82 refinements
# Processed 20 image
# 53 refinements
# Processed 20 image
# 55 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 46 refinements
# Processed 20 image
# 78 refinements
# Processed 20 image
# 45 refinements
# Processed 20 image
# 40 refinements
# Processed 20 image
# 14 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 70 refinements
# Processed 20 image
# 69 refinements
# Processed 20 image
# 42 refinements
# Processed 20 image
# 28 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 67 refinements
# Processed 20 image
# 80 refinements
# Processed 20 image
# 61 refinements
# Processed 20 image
# 45 refinements
# Processed 20 image
# 10 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 66 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 75 refinements
# Processed 20 image
# 41 refinements
# Processed 20 image
# 17 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 87 refinements
# Processed 20 image
# 80 refinements
# Processed 20 image
# 58 refinements
# Processed 20 image
# 34 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 73 refinements
# Processed 20 image
# 71 refinements
# Processed 20 image
# 59 refinements
# Processed 20 image
# 48 refinements
# Processed 20 image
# 10 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 96 refinements
# Processed 20 image
# 61 refinements
# Processed 20 image
# 53 refinements
# Processed 20 image
# 41 refinements
# Processed 20 image
# 7 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 78 refinements
# Processed 20 image
# 76 refinements
# Processed 20 image
# 58 refinements
# Processed 20 image
# 34 refinements
# Processed 20 image
# 8 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 64 refinements
# Processed 20 image
# 60 refinements
# Processed 20 image
# 45 refinements
# Processed 20 image
# 46 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 90 refinements
# Processed 20 image
# 90 refinements
# Processed 20 image
# 59 refinements
# Processed 20 image
# 32 refinements
# Processed 20 image
# 10 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 103 refinements
# Processed 20 image
# 93 refinements
# Processed 20 image
# 61 refinements
# Processed 20 image
# 42 refinements
# Processed 20 image
# 13 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 81 refinements
# Processed 20 image
# 90 refinements
# Processed 20 image
# 55 refinements
# Processed 20 image
# 30 refinements
# Processed 20 image
# 13 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 81 refinements
# Processed 20 image
# 66 refinements
# Processed 20 image
# 33 refinements
# Processed 20 image
# 27 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 49 refinements
# Processed 20 image
# 54 refinements
# Processed 20 image
# 55 refinements
# Processed 20 image
# 16 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 82 refinements
# Processed 20 image
# 82 refinements
# Processed 20 image
# 60 refinements
# Processed 20 image
# 21 refinements
# Processed 20 image
# 6 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 48 refinements
# Processed 20 image
# 46 refinements
# Processed 20 image
# 51 refinements
# Processed 20 image
# 30 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 60 refinements
# Processed 20 image
# 59 refinements
# Processed 20 image
# 61 refinements
# Processed 20 image
# 32 refinements
# Processed 20 image
# 10 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 89 refinements
# Processed 20 image
# 90 refinements
# Processed 20 image
# 41 refinements
# Processed 20 image
# 15 refinements
# Processed 20 image
# 7 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 86 refinements
# Processed 20 image
# 85 refinements
# Processed 20 image
# 56 refinements
# Processed 20 image
# 44 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 26 refinements
# Processed 20 image
# 87 refinements
# Processed 20 image
# 49 refinements
# Processed 20 image
# 41 refinements
# Processed 20 image
# 13 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 51 refinements
# Processed 20 image
# 51 refinements
# Processed 20 image
# 70 refinements
# Processed 20 image
# 29 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 76 refinements
# Processed 20 image
# 73 refinements
# Processed 20 image
# 49 refinements
# Processed 20 image
# 43 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 86 refinements
# Processed 20 image
# 84 refinements
# Processed 20 image
# 63 refinements
# Processed 20 image
# 49 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 81 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 64 refinements
# Processed 20 image
# 34 refinements
# Processed 20 image
# 6 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 85 refinements
# Processed 20 image
# 91 refinements
# Processed 20 image
# 53 refinements
# Processed 20 image
# 33 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 72 refinements
# Processed 20 image
# 71 refinements
# Processed 20 image
# 43 refinements
# Processed 20 image
# 41 refinements
# Processed 20 image
# 10 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 56 refinements
# Processed 20 image
# 57 refinements
# Processed 20 image
# 76 refinements
# Processed 20 image
# 48 refinements
# Processed 20 image
# 15 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 64 refinements
# Processed 20 image
# 44 refinements
# Processed 20 image
# 46 refinements
# Processed 20 image
# 37 refinements
# Processed 20 image
# 9 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 44 refinements
# Processed 20 image
# 31 refinements
# Processed 20 image
# 13 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 74 refinements
# Processed 20 image
# 74 refinements
# Processed 20 image
# 54 refinements
# Processed 20 image
# 36 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 64 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 62 refinements
# Processed 20 image
# 28 refinements
# Processed 20 image
# 8 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 74 refinements
# Processed 20 image
# 90 refinements
# Processed 20 image
# 56 refinements
# Processed 20 image
# 40 refinements
# Processed 20 image
# 14 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 81 refinements
# Processed 20 image
# 76 refinements
# Processed 20 image
# 47 refinements
# Processed 20 image
# 31 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 55 refinements
# Processed 20 image
# 59 refinements
# Processed 20 image
# 56 refinements
# Processed 20 image
# 34 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 71 refinements
# Processed 20 image
# 71 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 29 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 51 refinements
# Processed 20 image
# 24 refinements
# Processed 20 image
# 6 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 56 refinements
# Processed 20 image
# 46 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 74 refinements
# Processed 20 image
# 74 refinements
# Processed 20 image
# 56 refinements
# Processed 20 image
# 43 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 60 refinements
# Processed 20 image
# 60 refinements
# Processed 20 image
# 61 refinements
# Processed 20 image
# 31 refinements
# Processed 20 image
# 5 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 69 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 58 refinements
# Processed 20 image
# 61 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 100 refinements
# Processed 20 image
# 100 refinements
# Processed 20 image
# 57 refinements
# Processed 20 image
# 41 refinements
# Processed 20 image
# 13 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 42 refinements
# Processed 20 image
# 75 refinements
# Processed 20 image
# 66 refinements
# Processed 20 image
# 32 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 42 refinements
# Processed 20 image
# 42 refinements
# Processed 20 image
# 55 refinements
# Processed 20 image
# 34 refinements
# Processed 20 image
# 6 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 71 refinements
# Processed 20 image
# 76 refinements
# Processed 20 image
# 49 refinements
# Processed 20 image
# 38 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 82 refinements
# Processed 20 image
# 82 refinements
# Processed 20 image
# 49 refinements
# Processed 20 image
# 39 refinements
# Processed 20 image
# 7 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 69 refinements
# Processed 20 image
# 67 refinements
# Processed 20 image
# 67 refinements
# Processed 20 image
# 20 refinements
# Processed 20 image
# 13 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 69 refinements
# Processed 20 image
# 68 refinements
# Processed 20 image
# 54 refinements
# Processed 20 image
# 35 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 78 refinements
# Processed 20 image
# 73 refinements
# Processed 20 image
# 55 refinements
# Processed 20 image
# 22 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 66 refinements
# Processed 20 image
# 65 refinements
# Processed 20 image
# 61 refinements
# Processed 20 image
# 37 refinements
# Processed 20 image
# 8 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 74 refinements
# Processed 20 image
# 73 refinements
# Processed 20 image
# 62 refinements
# Processed 20 image
# 29 refinements
# Processed 20 image
# 12 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 74 refinements
# Processed 20 image
# 89 refinements
# Processed 20 image
# 62 refinements
# Processed 20 image
# 38 refinements
# Processed 20 image
# 11 refinements
# Processed 20 image
# 0 refinements
# Processed 20 image
# 39 refinements
# Processed 20 image
# 41 refinements
# Processed 20 image
# 54 refinements
# Processed 20 image
# 26 refinements
# Processed 20 image
# 8 refinements
# Processed 20 image
# 0 refinements
# ┌ Info: 1
# └ @ Main In[3]:11
# ┌ Info: 2
# └ @ Main In[3]:11
# ┌ Info: 3
# └ @ Main In[3]:11
# ┌ Info: 4
# └ @ Main In[3]:11
# ┌ Info: 5
# └ @ Main In[3]:11
# ┌ Info: 6
# └ @ Main In[3]:11
# ┌ Info: 7
# └ @ Main In[3]:11
# ┌ Info: 8
# └ @ Main In[3]:11
# ┌ Info: 9
# └ @ Main In[3]:11
# ┌ Info: 10
# └ @ Main In[3]:11
# ┌ Info: 11
# └ @ Main In[3]:11
# ┌ Info: 12
# └ @ Main In[3]:11
# ┌ Info: 13
# └ @ Main In[3]:11
# ┌ Info: 14
# └ @ Main In[3]:11
# ┌ Info: 15
# └ @ Main In[3]:11
# ┌ Info: 16
# └ @ Main In[3]:11
# ┌ Info: 17
# └ @ Main In[3]:11
# ┌ Info: 18
# └ @ Main In[3]:11
# ┌ Info: 19
# └ @ Main In[3]:11
# ┌ Info: 20
# └ @ Main In[3]:11
# ┌ Info: 21
# └ @ Main In[3]:11
# ┌ Info: 22
# └ @ Main In[3]:11
# ┌ Info: 23
# └ @ Main In[3]:11
# ┌ Info: 24
# └ @ Main In[3]:11
# ┌ Info: 25
# └ @ Main In[3]:11
# ┌ Info: 26
# └ @ Main In[3]:11
# ┌ Info: 27
# └ @ Main In[3]:11
# ┌ Info: 28
# └ @ Main In[3]:11
# ┌ Info: 29
# └ @ Main In[3]:11
# ┌ Info: 30
# └ @ Main In[3]:11
# ┌ Info: 31
# └ @ Main In[3]:11
# ┌ Info: 32
# └ @ Main In[3]:11
# ┌ Info: 33
# └ @ Main In[3]:11
# ┌ Info: 34
# └ @ Main In[3]:11
# ┌ Info: 35
# └ @ Main In[3]:11
# ┌ Info: 36
# └ @ Main In[3]:11
# ┌ Info: 37
# └ @ Main In[3]:11
# ┌ Info: 38
# └ @ Main In[3]:11
# ┌ Info: 39
# └ @ Main In[3]:11
# ┌ Info: 40
# └ @ Main In[3]:11
# ┌ Info: 41
# └ @ Main In[3]:11
# ┌ Info: 42
# └ @ Main In[3]:11
# ┌ Info: 43
# └ @ Main In[3]:11
# ┌ Info: 44
# └ @ Main In[3]:11
# ┌ Info: 45
# └ @ Main In[3]:11
# ┌ Info: 46
# └ @ Main In[3]:11
# ┌ Info: 47
# └ @ Main In[3]:11
# ┌ Info: 48
# └ @ Main In[3]:11
# ┌ Info: 49
# └ @ Main In[3]:11
# ┌ Info: 50
# └ @ Main In[3]:11
# ┌ Info: 51
# └ @ Main In[3]:11
# ┌ Info: 52
# └ @ Main In[3]:11
# ┌ Info: 53
# └ @ Main In[3]:11
# ┌ Info: 54
# └ @ Main In[3]:11
# ┌ Info: 55
# └ @ Main In[3]:11
# ┌ Info: 56
# └ @ Main In[3]:11
# ┌ Info: 57
# └ @ Main In[3]:11
# ┌ Info: 58
# └ @ Main In[3]:11
# ┌ Info: 59
# └ @ Main In[3]:11
# ┌ Info: 60
# └ @ Main In[3]:11
# ┌ Info: 61
# └ @ Main In[3]:11
# ┌ Info: 62
# └ @ Main In[3]:11
# ┌ Info: 63
# └ @ Main In[3]:11
# ┌ Info: 64
# └ @ Main In[3]:11
# ┌ Info: 65
# └ @ Main In[3]:11
# ┌ Info: 66
# └ @ Main In[3]:11
# ┌ Info: 67
# └ @ Main In[3]:11
# ┌ Info: 68
# └ @ Main In[3]:11
# ┌ Info: 69
# └ @ Main In[3]:11
# ┌ Info: 70
# └ @ Main In[3]:11
# ┌ Info: 71
# └ @ Main In[3]:11
# ┌ Info: 72
# └ @ Main In[3]:11
# ┌ Info: 73
# └ @ Main In[3]:11
# ┌ Info: 74
# └ @ Main In[3]:11
# ┌ Info: 75
# └ @ Main In[3]:11
# ┌ Info: 76
# └ @ Main In[3]:11
# ┌ Info: 77
# └ @ Main In[3]:11
# ┌ Info: 78
# └ @ Main In[3]:11
# ┌ Info: 79
# └ @ Main In[3]:11
# ┌ Info: 80
# └ @ Main In[3]:11
# ┌ Info: 81
# └ @ Main In[3]:11
# ┌ Info: 82
# └ @ Main In[3]:11
# ┌ Info: 83
# └ @ Main In[3]:11
# ┌ Info: 84
# └ @ Main In[3]:11
# ┌ Info: 85
# └ @ Main In[3]:11
# ┌ Info: 86
# └ @ Main In[3]:11
# ┌ Info: 87
# └ @ Main In[3]:11
# ┌ Info: 88
# └ @ Main In[3]:11
# ┌ Info: 89
# └ @ Main In[3]:11
# ┌ Info: 90
# └ @ Main In[3]:11
# ┌ Info: 91
# └ @ Main In[3]:11
# ┌ Info: 92
# └ @ Main In[3]:11
# ┌ Info: 93
# └ @ Main In[3]:11
# ┌ Info: 94
# └ @ Main In[3]:11
# ┌ Info: 95
# └ @ Main In[3]:11
# ┌ Info: 96
# └ @ Main In[3]:11
# ┌ Info: 97
# └ @ Main In[3]:11
# ┌ Info: 98
# └ @ Main In[3]:11
# ┌ Info: 99
# └ @ Main In[3]:11
# ┌ Info: 100
# └ @ Main In[3]:11

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
plot(T ./ 10.0, loss_over_lambdas_array[1] / 100.0, xaxis=:log, framestyle=:box, 
     xlabel="theresh [nm]", ylabel="loss [nm^2]", label=nothing, linewidth=0.5, dpi=150, fmt=:png, color=1, 
     xtickfontsize=12, ytickfontsize=12, legendfontsize=12)

l_mean = deepcopy(loss_over_lambdas_array[1] ./ 100.0)
for i = 2:nrealization
    plot!(T ./ 10.0, loss_over_lambdas_array[i] ./ 100.0, xaxis=:log, framestyle=:box, 
          xlabel="thresh [nm]", ylabel="loss [nm^2]", 
          label=nothing, linewidth=0.5, dpi=150, fmt=:png, color=1)
    l_mean .+= (loss_over_lambdas_array[i] ./ 100.0)
end
l_mean .= l_mean ./ nrealization

l_std = deepcopy(l_mean)
l_std .= 0.0
for i = 1:nrealization
    l_std .+= ((loss_over_lambdas_array[i] ./ 100.0) .- l_mean).^2
end
l_std .= l_std ./ (nrealization - 1.0)

#plot!(lambdas, l_mean, ribbon=l_std, fillalpha=0.5, color=1, linewidth=0.0, legend=nothing)

ylims!(-0.05, 4.0)
xlabel!("thresh [nm]", fontsize=35)
p = ylabel!("Loss [nm^2]", fontsize=35)

# %%
savefig(p, "blindtip_originalreg_randn01.png")

# %%
it = 4
islice = 5
cutoff = 80.0

plot(collect(1:nx) .* resolution ./ 10.0, P_over_lambdas_array[1][it][islice, :] / 10.0, linewidth=0.5, linestyle=:dot, color=1, label=nothing, framestyle=:box, dpi=150, fmt=:png, legend=nothing)
p_mean = deepcopy(P_over_lambdas_array[1][it][islice, :] ./ 10.0)
for irealization = 2:nrealization
    plot!(collect(1:nx) .* resolution ./ 10.0, P_over_lambdas_array[irealization][it][islice, :] / 10.0, linewidth=0.5, linestyle=:dot, color=1, label=nothing, framestyle=:box, dpi=150, fmt=:png, legend=nothing)
    p_mean .+= P_over_lambdas_array[irealization][it][islice, :] ./ 10.0
end
p_mean .= p_mean ./ nrealization

p_std = deepcopy(p_mean)
p_std .= 0.0
for irealization = 1:nrealization
    p_std .+= (P_over_lambdas_array[irealization][it][islice, :] ./ 10.0 .- p_mean).^2
end
p_std .= p_std ./ (nrealization - 1.0)

plot!(collect(1:nx) .* resolution ./ 10.0, p_mean, ribbon=p_std, fillalpha=0.3, color=1)

plot!((collect(1:nx)) .* resolution ./ 10.0, tip[islice, :] ./ 10.0, linewidth=3, label="ground truth", legend=nothing, color=2, 
      xtickfontsize=12, ytickfontsize=12, legendfontsize=12)

ylims!((-10, 0.5))
xlims!((1, 20))
xlabel!("X coordinate [nm]", fontsize=35)
p = ylabel!("Tip height [nm]", fontsize=35)

# %%
it = 4
islice = 5

plot(collect(1:ny) .* resolution ./ 10.0, P_over_lambdas_array[1][it][:, islice+2] / 10.0, 
    linewidth=0.5, linestyle=:dot, color=1, label=nothing, framestyle=:box, dpi=150, fmt=:png, legend=nothing)
p_mean = deepcopy(P_over_lambdas_array[1][it][:, islice+2] ./ 10.0)
for irealization = 2:nrealization
    plot!(collect(1:ny) .* resolution / 10.0, P_over_lambdas_array[irealization][it][:, islice+2] ./ 10.0, 
        linewidth=0.5, linestyle=:dot, color=1, label=nothing, framestyle=:box, dpi=150, fmt=:png, legend=nothing)
    p_mean .+= P_over_lambdas_array[irealization][it][:, islice+2] ./ 10.0
end
p_mean .= p_mean ./ nrealization

p_std = deepcopy(p_mean)
p_std .= 0.0
for irealization = 1:nrealization
    p_std .+= (P_over_lambdas_array[irealization][it][:, islice+2] ./ 10.0 .- p_mean).^2
end
p_std .= p_std ./ (nrealization - 1.0)

plot!(collect(1:ny) .* resolution ./ 10.0, p_mean, ribbon=p_std, fillalpha=0.3, color=1, linewidth=0.0)

plot!((collect(1:ny)) .* resolution ./ 10.0, tip[:, islice] / 10.0, linewidth=3, label="ground truth", legend=nothing, color=2, 
      xtickfontsize=12, ytickfontsize=12, legendfontsize=12)

ylims!((-10, 0.5))
xlims!((1, 20))

xlabel!("Y coordinate [nm]", fontsize=35)
p = ylabel!("Tip height [nm]", fontsize=35)

# %%
savefig(p, "blindtip_originalreg_randn02.png")

# %%
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
tip_tmp = deepcopy(tip)
tip_tmp[tip .< -150.0] .= NaN

plot(collect(1:nx) .* resolution ./ 10.0, collect(1:ny) .* resolution ./ 10.0, tip_tmp ./ 10.0, st=:surface, dpi=150, clim=(-12, 0),
     xtickfontsize=12, ytickfontsize=12, legendfontsize=12, colorbar_tickfontsize=12)
xlabel!("Y [nm]", fontsize=35)
p = ylabel!("X [nm]", fontsize=35)
#zlabel!("Z [nm]", fontsize=35)
#zlims!((-8, 0.5))
#zlabel!("Tip height [nm]", fontsize=35)

# %%
savefig(p, "blindtip_originalreg_randn04.png")

# %%
tip_tmp = deepcopy(P_over_lambdas_array[1][1])
tip_tmp[tip .< -120.0] .= NaN

plot(collect(1:nx) .* resolution ./ 10.0, collect(1:ny) .* resolution ./ 10.0, tip_tmp ./ 10.0, st=:surface, dpi=150, clim=(-12, 0), 
     xtickfontsize=12, ytickfontsize=12, legendfontsize=12, colorbar_tickfontsize=12)
zlims!((-8, 0.5))
xlabel!("Y [nm]", fontsize=35)
p = ylabel!("X [nm]", fontsize=35)
#zlabel!("Tip height [nm]", fontsize=35)

# %%
savefig(p, "blindtip_originalreg_randn05.png")

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
p = heatmap(collect(1:30) .* resolution / 10.0, collect(1:30) .* resolution / 10.0, images_randn[1] / 10.0, clim=(0, 8), dpi=150, fmt=:png, aspect_ratio=:equal, 
    xtickfontsize=12, ytickfontsize=12, legendfontsize=12, colorbar_tickfontsize=12)
xlabel!("X coordinate [nm]", fontsize=35)
ylabel!("Y coordinate [nm]", fontsize=35)
xlims!(13, 32)
ylims!(14, 32)

# %%
savefig(p, "blindtip_originalreg_randn06.png")

# %%
p = heatmap(collect(1:30) .* resolution / 10.0, collect(1:30) .* resolution / 10.0, ierosion(images_randn[1], P_over_lambdas_array[1][4]) / 10.0, clim=(0, 8), dpi=150, fmt=:png, aspect_ratio=:equal,
    xtickfontsize=12, ytickfontsize=12, legendfontsize=12, colorbar_tickfontsize=12)
xlabel!("X coordinate [nm]", fontsize=35)
ylabel!("Y coordinate [nm]", fontsize=35)
xlims!(13, 32)
ylims!(14, 32)

# %%
savefig(p, "blindtip_originalreg_randn07.png")

# %%
p = heatmap(collect(1:30) .* resolution / 10.0, collect(1:30) .* resolution / 10.0, surfs[1] / 10.0, clim=(0, 8), dpi=150, fmt=:png, aspect_ratio=:equal, 
            xtickfontsize=12, ytickfontsize=12, legendfontsize=12, colorbar_tickfontsize=12)
xlabel!("X coordinate [nm]", fontsize=35)
ylabel!("Y coordinate [nm]", fontsize=35)
xlims!(13, 32)
ylims!(14, 32)

# %%
savefig(p, "blindtip_originalreg_randn08.png")

# %% [markdown]
# # Pixel RMSD of reconstructed tip

# %%
function pixel_rmsd(image1, image2, ref; cutoff = -70.0)
    image1_shifted = similar(image1)

    rmsd_min = Inf64
    for du = -5:5, dv = -5:5
        image1_shifted = circshift(image1, (du, dv))
        #id = (image1_shifted .> cutoff) .| (image2 .> cutoff)
        id = ref .> cutoff
        tmp = sqrt(mean((image1_shifted[id] .- image2[id]).^2))
        if tmp < rmsd_min
            rmsd_min = tmp
        end
    end
    return rmsd_min
end

diff_tip = zeros(Float64, length(T)*nrealization, 2)
count = 0
for it = 1:length(T)
    for ireal = 1:nrealization
        c = pixel_rmsd(P_over_lambdas_array[ireal][it], tip, tip, cutoff=-80.0)
        count += 1
        diff_tip[count, 1] = T[it]
        diff_tip[count, 2] = c
    end
end

# %%
using StatsPlots
pyplot()

violin(log10.(diff_tip[:, 1] ./ 10.0), diff_tip[:, 2] ./ 10.0, 
       xtickfontsize=12, ytickfontsize=12, legendfontsize=12, 
       framestyle=:box, label=nothing, linewidth=0.5, dpi=150, fmt=:png, alpha=0.6, color=1)

dotplot!(log10.(diff_tip[:, 1] ./ 10.0), diff_tip[:, 2] ./ 10.0, marker=(:black,stroke(0)), mode = :density, markersize=2.0, label=nothing)

#scatter(diff_tip[:, 1] / 10.0, diff_tip[:, 2] / 10.0, xaxis=:log, framestyle = :box, xlabel="threshold T", ylabel="RMSD frome true tip [nm]", label=nothing, linewidth=1.0, markershape=:circle, dpi=150, fmt=:png, color=1, 
#        xtickfontsize=12, ytickfontsize=12, legendfontsize=10, colorbar_tickfontsize=10, markersize=12, markerstrokewidth=1)
#ylims!(-0.05, 2.3)
xlabel!("log T [nm]", fontsize=35)
p = ylabel!("RMSD from true tip [nm]", fontsize=35)
xlims!(-2.5, 1.5)
ylims!(0.0, 6.5)

# %% [markdown]
# # Pixel RMSD of reconstructed surface

# %%
diff_surf = zeros(Float64, length(T)*nrealization*nframe, 2)
count = 0
Random.seed!(777);
images_randn = deepcopy(images)

for it = 1:length(T)
    for ireal = 1:nrealization
        for iframe = 1:nframe
            images_randn[iframe] .= images[iframe] .+ 3.0 .* randn(Float64, size(images[iframe]))
            c = pixel_rmsd(ierosion(images_randn[iframe], P_over_lambdas_array[ireal][it]), surfs[iframe], images[iframe], cutoff=10.0)
            count += 1
            diff_surf[count, 1] = T[it]
            diff_surf[count, 2] = c
        end
    end
end

# %%
using StatsPlots
pyplot()

violin(log10.(diff_surf[:, 1] ./ 10.0), diff_surf[:, 2] / 10.0, ylim=(-0.1, 6.0),
       xtickfontsize=12, ytickfontsize=12, legendfontsize=12, 
       xlabel="log lambda", ylabel="RMSD from true surface [nm]", 
       framestyle=:box, label=nothing, linewidth=0.5, dpi=150, fmt=:png, alpha=0.6, color=1)

dotplot!(log10.(diff_surf[:, 1] ./ 10.0), diff_surf[:, 2] / 10.0, marker=(:black, stroke(0)), markersize=0.5, mode = :density, label=nothing)

ylims!(-0.0, 5.0)

# %% [markdown]
# # Save results

# %%
using BSON: @save, @load

@save "blindtip_originalreg_randn.bson" tip images nframe nrealization T P_over_lambdas_array diff_tip diff_surf
